# %%
import numpy as np
import cv2
COLOR_BayerBG2BGR = 46
COLOR_BayerGB2BGR = 47
COLOR_BayerRG2BGR = 48
COLOR_BayerGR2BGR = 49
from matplotlib import pyplot as plt

# %%
f = file("/home/niggi/Desktop/5_raw.bin","rb")
while True:
    try:
        aa = np.load(f)
        aa = cv2.cvtColor(aa,COLOR_BayerRG2BGR)
        plt.imshow(aa)
        plt.show()
    except:
        break
        
        
f.close()
